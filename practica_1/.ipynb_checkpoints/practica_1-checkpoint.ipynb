# %% [markdown]
# ### 1.
#
# Escoger un corpus de cualquier idioma y de un tamaño mayor a 10 000 tokens.

# %%
import nltk

nltk.download('brown')
# Out:
# [nltk_data] Downloading package brown to
# [nltk_data]     /Users/ldanieldesanpedro/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# True

# %%
from nltk.corpus import brown

sentences = brown.sents()
print(sentences[0])
# Out:
# ['The', 'Fulton', 'County', 'Grand', 'Jury', 'said', 'Friday', 'an', 'investigation', 'of', "Atlanta's", 'recent', 'primary', 'election', 'produced', '``', 'no', 'evidence', "''", 'that', 'any', 'irregularities', 'took', 'place', '.']

# %% [markdown]
# ## 2.
#
# Limpiar los signos de puntuación, de admiración, de interrogación y cualquier elemento no léxico.

# %%
import re
def identify(word):
    result = re.findall(r'[^ a-z A-Z|-]', word)
    return len(result) == 0

# %%
print(identify('hello!'))
print(identify('hello'))
print(identify('``'))
print(identify('.'))
print(identify('!'))
print(identify('Hello-there'))
# Out:
# False
# True
# False
# False
# False
# True

# %%
cleaned_corpus = list(map(lambda word: list(filter(identify,word)),sentences))

# %%
print(cleaned_corpus[0])
# Out:
# ['The', 'Fulton', 'County', 'Grand', 'Jury', 'said', 'Friday', 'an', 'investigation', 'of', 'recent', 'primary', 'election', 'produced', 'no', 'evidence', 'that', 'any', 'irregularities', 'took', 'place']

# %%
print(sentences[0])
print(type(sentences[0]))
# Out:
# ['The', 'Fulton', 'County', 'Grand', 'Jury', 'said', 'Friday', 'an', 'investigation', 'of', "Atlanta's", 'recent', 'primary', 'election', 'produced', '``', 'no', 'evidence', "''", 'that', 'any', 'irregularities', 'took', 'place', '.']
# <class 'list'>

# %% [markdown]
# # 3.

# %%
from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer('english')
print(stemmer.stem('executive'))
print(stemmer.stem('execution'))
print(stemmer.stem('execute'))
# Out:
# execut
# execut
# execut

# %%
#Aplicamos stemming a cada palabra de cada oracion en el corpus limpio
corpus_stemmed = list([list(map(stemmer.stem,sentence)) for sentence in cleaned_corpus])

# %%
print(corpus_stemmed[0])
# Out:
# ['the', 'fulton', 'counti', 'grand', 'juri', 'said', 'friday', 'an', 'investig', 'of', 'recent', 'primari', 'elect', 'produc', 'no', 'evid', 'that', 'ani', 'irregular', 'took', 'place']

# %%
#Juntamos todos los stemms de las oraciones en una sola collección

joined_stemms = [stemm for sentence in corpus_stemmed for stemm in sentence]

# %%
print(joined_stemms[0])
print(joined_stemms[1])
# Out:
# the
# fulton

# %%
print(len(joined_stemms))
# Out:
# 992136

# %%
stemms = dict()

for (index,stemm) in zip(range(0,len(joined_stemms)),joined_stemms):
    print("\r index {} of {}".format(index,len(joined_stemms)), end = "\r")
    try:
        stemms[stemm] = stemms[stemm] + 1
    except KeyError:
        stemms[stemm] = 1
# Out:
#  index 890 of 992136
#  index 1390 of 992136
#  index 2389 of 992136
#  index 2889 of 992136
#  index 3888 of 992136
#  index 4388 of 992136
#  index 5387 of 992136
#  index 5887 of 992136
#  index 6886 of 992136
#  index 7386 of 992136
#  index 7990 of 992136
#  index 8467 of 992136
#  index 9384 of 992136
#  index 9884 of 992136
#  index 10883 of 992136
#  index 11383 of 992136
#  index 11958 of 992136
#  index 12382 of 992136
#  index 13151 of 992136
#  index 13881 of 992136
#  index 14516 of 992136
#  index 15380 of 992136
#  index 15879 of 992136
#  index 16879 of 992136
#  index 17378 of 992136
#  index 18378 of 992136
#  index 18877 of 992136
#  index 19770 of 992136
#  index 20286 of 992136
#  index 21376 of 992136
#  index 21866 of 992136
#  index 22844 of 992136
#  index 23255 of 992136
#  index 24374 of 992136
#  index 24766 of 992136
#  index 25442 of 992136
#  index 25872 of 992136
#  index 26919 of 992136
#  index 27371 of 992136
#  index 27871 of 992136
#  index 28355 of 992136
#  index 29080 of 992136
#  index 29643 of 992136
#  index 30323 of 992136
#  index 30868 of 992136
#  index 31738 of 992136
#  index 32116 of 992136
#  index 32619 of 992136
#  index 33152 of 992136
#  index 33733 of 992136
#  index 34865 of 992136
#  index 35444 of 992136
#  index 36364 of 992136
#  index 36837 of 992136
#  index 37498 of 992136
#  index 37931 of 992136
#  index 38363 of 992136
#  index 39514 of 992136
#  index 39861 of 992136
#  index 40593 of 992136
#  index 41275 of 992136
#  index 41965 of 992136
#  index 42633 of 992136
#  index 43416 of 992136
#  index 44074 of 992136
#  index 45154 of 992136
#  index 45669 of 992136
#  index 46483 of 992136
#  index 47142 of 992136
#  index 48111 of 992136
#  index 48709 of 992136
#  index 49460 of 992136
#  index 50154 of 992136
#  index 50964 of 992136
#  index 51659 of 992136
#  index 52498 of 992136
#  index 53174 of 992136
#  index 53947 of 992136
#  index 54703 of 992136
#  index 55776 of 992136
#  index 56605 of 992136
#  index 57350 of 992136
#  index 57959 of 992136
#  index 58717 of 992136
#  index 59589 of 992136
#  index 60348 of 992136
#  index 992135 of 992136

# %%
print(stemms)
# Out:
# {'the': 69971, 'fulton': 17, 'counti': 190, 'grand': 54, 'juri': 68, 'said': 1961, 'friday': 63, 'an': 3740, 'investig': 131, 'of': 36413, 'recent': 302, 'primari': 98, 'elect': 171, 'produc': 256, 'no': 2139, 'evid': 290, 'that': 10594, 'ani': 1346, 'irregular': 27, 'took': 428, 'place': 823, 'further': 223, 'in': 21337, 'term-end': 1, 'present': 583, 'citi': 500, 'execut': 104, 'committe': 186, 'which': 3561, 'had': 5133, 'over-al': 35, 'charg': 232, 'deserv': 42, 'prais': 34, 'and': 28853, 'thank': 90, 'atlanta': 35, 'for': 9489, 'manner': 143, 'was': 9815, 'conduct': 134, 'september-octob': 1, 'term': 258, 'been': 2472, 'by': 5306, 'superior': 64, 'court': 286, 'judg': 127, 'durwood': 1, 'pye': 1, 'to': 26158, 'report': 457, 'possibl': 565, 'hard-fought': 2, 'won': 68, 'mayor-nomin': 1, 'ivan': 4, 'allen': 20, 'onli': 1748, 'a': 23195, 'relat': 459, 'hand': 781, 'such': 1303, 'receiv': 311, 'consid': 340, 'widespread': 30, 'interest': 603, 'number': 613, 'voter': 24, 'size': 154, 'this': 5145, 'it': 10618, 'did': 1044, 'find': 546, 'mani': 1030, 'registr': 30, 'law': 389, 'are': 4395, 'outmod': 4, 'or': 4207, 'inadequ': 34, 'often': 370, 'ambigu': 40, 'recommend': 127, 'legisl': 115, 'act': 401, 'have': 4221, 'these': 1574, 'studi': 468, 'revis': 39, 'end': 570, 'modern': 230, 'improv': 181, 'them': 1788, 'comment': 100, 'on': 6741, 'other': 2025, 'topic': 23, 'among': 370, 'purchas': 104, 'depart': 278, 'well': 910, 'oper': 473, 'follow': 587, 'general': 673, 'accept': 267, 'practic': 300, 'inur': 4, 'best': 353, 'both': 730, 'govern': 524, 'merger': 26, 'propos': 180, 'howev': 552, 'believ': 345, 'two': 1412, 'offic': 485, 'should': 888, 'be': 7125, 'combin': 151, 'achiev': 217, 'greater': 188, 'effici': 93, 'reduc': 180, 'cost': 428, 'administr': 235, 'is': 10109, 'lack': 167, 'experienc': 60, 'cleric': 10, 'personnel': 75, 'as': 7253, 'result': 490, 'polici': 290, 'urg': 76, 'take': 874, 'step': 299, 'remedi': 20, 'problem': 560, 'implement': 21, 'automobil': 74, 'titl': 106, 'also': 1069, 'outgo': 8, 'next': 394, 'legislatur': 41, 'provid': 568, 'enabl': 57, 'fund': 158, 're-set': 1, 'effect': 535, 'date': 156, 'so': 1985, 'order': 538, 'may': 1417, 'swipe': 4, 'at': 5372, 'state': 1515, 'welfar': 53, 'handl': 126, 'feder': 265, 'grant': 131, 'child': 214, 'servic': 462, 'foster': 27, 'home': 619, 'one': 3410, 'major': 311, 'item': 133, 'assist': 175, 'program': 556, 'but': 4385, 'has': 2437, 'seen': 279, 'fit': 136, 'distribut': 136, 'through': 971, 'all': 3001, 'with': 7290, 'except': 275, 'none': 108, 'money': 268, 'juror': 8, 'they': 3620, 'realiz': 153, 'proportion': 18, 'might': 672, 'disabl': 21, 'our': 1279, 'less': 439, 'popul': 162, 'nevertheless': 73, 'we': 2652, 'feel': 494, 'futur': 227, 'some': 1618, 'portion': 73, 'avail': 275, 'failur': 93, 'do': 1532, 'will': 2334, 'continu': 490, 'disproportion': 3, 'burden': 55, 'taxpay': 33, 'under': 728, 'fire': 272, 'appoint': 84, 'apprais': 18, 'guardian': 13, 'award': 83, 'fee': 45, 'compens': 30, 'ward': 28, 'protect': 155, 'found': 572, 'incorpor': 22, 'into': 1791, 'procedur': 147, 'previous': 144, 'bar': 133, 'associ': 262, 'interim': 11, 'citizen': 116, 'action': 359, 'serv': 302, 'fact': 534, 'from': 4370, 'undu': 13, 'servant': 41, 'unmeritori': 1, 'critic': 190, 'regard': 192, 'new': 1635, 'multi-million-dollar': 2, 'airport': 23, 'when': 2331, 'manag': 273, 'elimin': 77, 'polit': 364, 'influenc': 164, 'not': 4610, 'elabor': 44, 'ad': 216, 'there': 2728, 'period': 337, 'surveil': 6, 'price': 180, 'concessionair': 9, 'purpos': 253, 'keep': 345, 'reason': 462, 'ask': 611, 'jail': 26, 'deputi': 30, 'matter': 377, 'four': 361, 'addit': 283, 'employ': 178, 'doctor': 135, 'medic': 167, 'intern': 235, 'extern': 47, 'night': 448, 'weekend': 34, 'duti': 97, 'work': 1177, 'offici': 161, 'pass': 338, 'permit': 170, 'establish': 256, 'fair': 147, 'equit': 13, 'pension': 22, 'plan': 522, 'polic': 159, 'tax': 268, 'bellwood': 1, 'alpharetta': 1, 'prison': 73, 'farm': ...

# %%
#Ordenamos los stemms en funcion de su frecuencia
sorted_freq = sorted(stemms.values(), reverse = True)

# %%
import math
##Obtenemos el logaritmo de las frecuencias
log_freq = map(lambda freq: math.log(freq),sorted_freq)
log_freq = list(log_freq)

# %%
##Creamos la lista con los rangos de las frecuencias
rang = list(range(1, len(log_freq) + 1))

# %%
##Sacamos el logaritmo de los rangos
log_rang = list(map(lambda rang: math.log(rang),rang))

# %%
import matplotlib.pyplot as plt
plt.scatter(log_rang,log_freq)

# %%
import numpy as np
mean_rang = np.mean(log_rang)
varia = sum(map(lambda x: (x - mean_rang)**2,log_rang)) / len(log_rang) -1
mean_fre = np.mean(log_freq)
print(mean_rang)
print(len(log_rang))
# Out:
# 9.275053074348873
# 28994

# %%
summatory = 0
for (x,y) in zip(log_rang,log_freq):
    summatory += (x - mean_rang) * (y - mean_fre)
print(summatory)

suma = np.dot((log_rang - mean_rang),(log_freq - mean_rang))
print(suma)

alpha = summatory / varia
# Out:
# -43416.18481860522
# -43416.1848186056

# %%
print(alpha)
# Out:
# 20446824.13259161
